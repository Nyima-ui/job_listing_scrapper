# %%
from helper import jobs_file_path
import pandas as pd

df = pd.read_json(jobs_file_path)
df
# Out:
#                                            job-title company-name  \
# 0          Senior Front-End Developer (React) Remote       Uplers
# 1                        Remote Full-Stack Developer       Turing
# 2  Senior Full Stack Engineer - (C#/.net & React ...       Uplers
# 3  Senior / Lead Full-Stack Engineer (AI-Accelera...       Uplers
#
#                       preferences          date-posted  \
# 0    [$35K/yr, Remote, Full-time]  Reposted 2 days ago
# 1             [Remote, Full-time]  Reposted 1 week ago
# 2    [$45K/yr, Remote, Full-time]         15 hours ago
# 3  [$44.4K/yr, Remote, Full-time]  Reposted 4 days ago
#
#                                       responsibility  \
# 0  * Lead the development of cutting-edge web app...
# 1  * Write clean, reusable, and maintainable code...
# 2  * Design, develop, and maintain scalable and p...
# 3  *   Strengthen and extend the existing prototy...
#
#                                          requirement  \
# ...

# %%
df["responsibility"] = df['responsibility'].str.replace("*", "•")

# %%
df = pd.read_json("")
# Out:
#                                            job-title company-name  \
# 0          Senior Front-End Developer (React) Remote       Uplers
# 1                        Remote Full-Stack Developer       Turing
# 2  Senior Full Stack Engineer - (C#/.net & React ...       Uplers
# 3  Senior / Lead Full-Stack Engineer (AI-Accelera...       Uplers
#
#                       preferences          date-posted  \
# 0    [$35K/yr, Remote, Full-time]  Reposted 2 days ago
# 1             [Remote, Full-time]  Reposted 1 week ago
# 2    [$45K/yr, Remote, Full-time]         15 hours ago
# 3  [$44.4K/yr, Remote, Full-time]  Reposted 4 days ago
#
#                                       responsibility  \
# 0  • Lead the development of cutting-edge web app...
# 1  • Write clean, reusable, and maintainable code...
# 2  • Design, develop, and maintain scalable and p...
# 3  •   Strengthen and extend the existing prototy...
#
#                                          requirement  \
# ...

# %%
df["requirement"] = df['requirement'].str.replace("*", "•")
df["responsibility"] = df['responsibility'].str.replace("*", "•").str.replace('\n', '\n')

# %%
df = pd.read_json(jobs_file_path)

# %%
df
# Out:
#                               job-title company-name          preferences  \
# 0  OXID ecommerce developer - Immediate   Codem Inc.  [Remote, Full-time]
# 1            Drupal Fullstack Developer      Specbee  [Remote, Full-time]
# 2                    Front end Engineer       Uplers  [Remote, Full-time]
#
#   date-posted                                     responsibility  \
# 0  3 days ago  *   Implement and maintain catalog, pricing/pr...
# 1  3 days ago  * Develop and maintain custom Drupal modules a...
# 2  1 week ago  * Build responsive web applications using Reac...
#
#                                          requirement  \
# 0  *   Immediate joiner\n*   6+ years developing ...
# 1  *   3+ years of experience in Drupal (7/8/9/10...
# 2  *   3+ years experience in Frontend Engineerin...
#
#                                             job-link
# 0  https://www.linkedin.com/jobs/collections/reco...
# 1  https://www.linkedin.com/jobs/collections/reco...
# ...
